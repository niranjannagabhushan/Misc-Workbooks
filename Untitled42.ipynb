# %%
height_dict = {
    "NAME1" : 20,
    "NAME2" : 40,
    "NAME3" : 60

}

# %%
list_1 = ["raj","ramesh","suresh"]

# %%
[i[::-1] for i in list_1]
# Out:
# ['jar', 'hsemar', 'hserus']

# %%
y= lambda a,b : a**b
print (y(2,3))
# Out:
# 8

# %%
list_2= [2,92,82,2,63]

# %%
set_list = set (list_2)

# %%
print (set_list)
# Out:
# {2, 92, 82, 63}

# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
print (df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
list_3 = [1,2,3]

# %%
list_4 =list_3

# %%
print(list_4)
# Out:
# [1, 2, 3]

# %%
list_4.append(5)

# %%
print(list_4)
# Out:
# [1, 2, 3, 5]

# %%
print(list_3)
# Out:
# [1, 2, 3, 5]

# %%
z=10
 
final_list = list(map(lambda x:x+z,list_3))

# %%
print(final_list)
# Out:
# [11, 12, 13, 15]
