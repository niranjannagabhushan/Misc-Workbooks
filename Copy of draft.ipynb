# %% [markdown]
# ### Problem statement:
# To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/gdrive/MyDrive/cancer_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path("/content/gdrive/MyDrive/cancer_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test")

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train, batch_size=batch_size, image_size=(img_height,
    img_width), shuffle=True, seed=123, validation_split=0.2,subset='training'
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_test, batch_size=batch_size, image_size=(img_height,
    img_width), shuffle=True, seed=123, validation_split=0.2,subset='validation'
)
# Out:
# Found 118 files belonging to 9 classes.
# Using 23 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

### your code goes here, you can use training or validation data to visualize
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here
model=Sequential([
                  layers.experimental.preprocessing.Rescaling(1./255,input_shape=(img_height,img_width,3)),
                  layers.Conv2D(16,3,padding='same',activation='relu'),
                  layers.MaxPool2D(),
                  layers.Conv2D(32,3,padding='same',activation='relu'),
                  layers.MaxPool2D(),
                  layers.Conv2D(64,3,padding='same',activation='relu'),
                  layers.MaxPool2D(),
                  layers.Flatten(),
                  layers.Dense(128,activation='relu'),
                  layers.Dense(9,activation='softmax')
              ])

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3,989,801
# Trainable params: 3,989,801
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 56/56 [==============================] - 483s 171ms/step - loss: 2.1228 - accuracy: 0.2081 - val_loss: 2.4973 - val_accuracy: 0.1739
# Epoch 2/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.6781 - accuracy: 0.4057 - val_loss: 2.3515 - val_accuracy: 0.3043
# Epoch 3/20
# 56/56 [==============================] - 1s 21ms/step - loss: 1.5032 - accuracy: 0.4877 - val_loss: 2.7935 - val_accuracy: 0.2609
# Epoch 4/20
# 56/56 [==============================] - 1s 21ms/step - loss: 1.3810 - accuracy: 0.5179 - val_loss: 2.2423 - val_accuracy: 0.2609
# Epoch 5/20
# 56/56 [==============================] - 1s 21ms/step - loss: 1.3025 - accuracy: 0.5430 - val_loss: 2.5830 - val_accuracy: 0.2609
# Epoch 6/20
# 56/56 [==============================] - 1s 21ms/step - loss: 1.2159 - accuracy: 0.5658 - val_loss: 2.4027 - val_accuracy: 0.2174
# Epoch 7/20
# 56/56 [==============================] - 1s 21ms/step - loss: 1.1716 - accuracy: 0.5859 - val_loss: 2.4933 - val_accuracy: 0.2174
# Epoch 8/20
# 56/56 [==============================] - 1s 21ms/step - loss: 1.0811 - accuracy: 0.6194 - val_loss: 2.4444 - val_accuracy: 0.2174
# Epoch 9/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.9977 - accuracy: 0.6390 - val_loss: 3.9802 - val_accuracy: 0.1739
# Epoch 10/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.9461 - accuracy: 0.6618 - val_loss: 4.3797 - val_accuracy: 0.2609
# Epoch 11/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.9365 - accuracy: 0.6641 - val_loss: 3.7341 - val_accuracy: 0.2609
# Epoch 12/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.7704 - accuracy: 0.7227 - val_loss: 3.9593 - val_accuracy: 0.1739
# Epoch 13/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.7454 - accuracy: 0.7204 - val_loss: 4.2209 - val_accuracy: 0.2609
# Epoch 14/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.7251 - accuracy: 0.7416 - val_loss: 4.2630 - val_accuracy: 0.2174
# Epoch 15/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.5694 - accuracy: 0.7902 - val_loss: 4.2548 - val_accuracy: 0.2609
# Epoch 16/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.5462 - accuracy: 0.8114 - val_loss: 5.6714 - val_accuracy: 0.1739
# Epoch 17/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4451 - accuracy: 0.8348 - val_loss: 5.2217 - val_accuracy: 0.1304
# Epoch 18/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4105 - accuracy: 0.8510 - val_loss: 6.4819 - val_accuracy: 0.2609
# Epoch 19/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4302 - accuracy: 0.8376 - val_loss: 6.8379 - val_accuracy: 0.2174
# Epoch 20/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.3895 - accuracy: 0.8666 - val_loss: 5.0690 - val_accuracy: 0.1304

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Write your findings here

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 
# Your code goes here

# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 
data_augument = keras.Sequential([
                             layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
                             layers.experimental.preprocessing.RandomRotation(0.2, fill_mode='reflect'),
                             layers.experimental.preprocessing.RandomZoom(height_factor=(0.2, 0.3), width_factor=(0.2, 0.3), fill_mode='reflect')
])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here

# Todo, visualize how your augmentation strategy works for one instance of training image.

plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(data_augument(images)[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here


## You can use Dropout layer if there is an evidence of overfitting in your findings
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([ data_augument,
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
      
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
epochs = 30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 56/56 [==============================] - 8s 89ms/step - loss: 2.0780 - accuracy: 0.1959 - val_loss: 2.2873 - val_accuracy: 0.1304
# Epoch 2/30
# 56/56 [==============================] - 5s 80ms/step - loss: 1.9211 - accuracy: 0.2863 - val_loss: 2.4642 - val_accuracy: 0.1304
# Epoch 3/30
# 56/56 [==============================] - 4s 80ms/step - loss: 1.7502 - accuracy: 0.3884 - val_loss: 2.3999 - val_accuracy: 0.2174
# Epoch 4/30
# 56/56 [==============================] - 4s 80ms/step - loss: 1.6855 - accuracy: 0.4057 - val_loss: 2.6714 - val_accuracy: 0.2609
# Epoch 5/30
# 56/56 [==============================] - 4s 80ms/step - loss: 1.5775 - accuracy: 0.4397 - val_loss: 2.4652 - val_accuracy: 0.2609
# Epoch 6/30
# 56/56 [==============================] - 4s 80ms/step - loss: 1.5489 - accuracy: 0.4448 - val_loss: 2.1911 - val_accuracy: 0.2609
# Epoch 7/30
# 56/56 [==============================] - 5s 82ms/step - loss: 1.6019 - accuracy: 0.4196 - val_loss: 2.3251 - val_accuracy: 0.3043
# Epoch 8/30
# 56/56 [==============================] - 4s 80ms/step - loss: 1.5241 - accuracy: 0.4581 - val_loss: 2.3753 - val_accuracy: 0.3043
# Epoch 9/30
# 56/56 [==============================] - 4s 80ms/step - loss: 1.5671 - accuracy: 0.4587 - val_loss: 2.8927 - val_accuracy: 0.2609
# Epoch 10/30
# 56/56 [==============================] - 5s 81ms/step - loss: 1.4885 - accuracy: 0.4782 - val_loss: 2.2004 - val_accuracy: 0.2609
# Epoch 11/30
# 56/56 [==============================] - 4s 80ms/step - loss: 1.4691 - accuracy: 0.4905 - val_loss: 2.8378 - val_accuracy: 0.2174
# Epoch 12/30
# 56/56 [==============================] - 4s 80ms/step - loss: 1.4687 - accuracy: 0.4905 - val_loss: 2.5066 - val_accuracy: 0.2609
# Epoch 13/30
# 56/56 [==============================] - 5s 80ms/step - loss: 1.4611 - accuracy: 0.4944 - val_loss: 2.3480 - val_accuracy: 0.2174
# Epoch 14/30
# 56/56 [==============================] - 4s 80ms/step - loss: 1.4540 - accuracy: 0.4916 - val_loss: 2.7005 - val_accuracy: 0.3043
# Epoch 15/30
# 56/56 [==============================] - 4s 80ms/step - loss: 1.4518 - accuracy: 0.4844 - val_loss: 2.1483 - val_accuracy: 0.2609
# Epoch 16/30
# 56/56 [==============================] - 4s 80ms/step - loss: 1.4329 - accuracy: 0.5022 - val_loss: 2.7201 - val_accuracy: 0.2609
# Epoch 17/30
# 56/56 [==============================] - 4s 80ms/step - loss: 1.4038 - accuracy: 0.5106 - val_loss: 2.6586 - val_accuracy: 0.3478
# Epoch 18/30
# 56/56 [==============================] - 4s 80ms/step - loss: 1.4265 - accuracy: 0.4983 - val_loss: 2.5191 - val_accuracy: 0.2609
# Epoch 19/30
# 56/56 [==============================] - 4s 80ms/step - loss: 1.4027 - accuracy: 0.5078 - val_loss: 2.6516 - val_accuracy: 0.2609
# Epoch 20/30
# 56/56 [==============================] - 4s 80ms/step - loss: 1.3487 - accuracy: 0.5212 - val_loss: 2.8806 - val_accuracy: 0.2609
# Epoch 21/30
# 56/56 [==============================] - 4s 80ms/step - loss: 1.3306 - accuracy: 0.5273 - val_loss: 2.3813 - val_accuracy: 0.3043
# Epoch 22/30
# 56/56 [==============================] - 4s 80ms/step - loss: 1.3184 - accuracy: 0.5368 - val_loss: 2.4109 - val_accuracy: 0.1739
# Epoch 23/30
# 56/56 [==============================] - 4s 80ms/step - loss: 1.3146 - accuracy: 0.5262 - val_loss: 2.6796 - val_accuracy: 0.2174
# Epoch 24/30
# 56/56 [==============================] - 4s 80ms/step - loss: 1.3089 - accuracy: 0.5491 - val_loss: 2.5950 - val_accuracy: 0.2609
# Epoch 25/30
# 56/56 [==============================] - 5s 80ms/step - loss: 1.2880 - accuracy: 0.5391 - val_loss: 3.0200 - val_accuracy: 0.2609
# Epoch 26/30
# 56/56 [==============================] - 5s 81ms/step - loss: 1.3020 - accuracy: 0.5340 - val_loss: 2.6334 - val_accuracy: 0.3043
# Epoch 27/30
# 56/56 [==============================] - 4s 80ms/step - loss: 1.3176 - accuracy: 0.5318 - val_loss: 2.3288 - val_accuracy: 0.3478
# Epoch 28/30
# 56/56 [==============================] - 4s 80ms/step - loss: 1.2732 - accuracy: 0.5430 - val_loss: 2.7221 - val_accuracy: 0.2174
# Epoch 29/30
# 56/56 [==============================] - 4s 80ms/step - loss: 1.2681 - accuracy: 0.5502 - val_loss: 3.0281 - val_accuracy: 0.1739
# Epoch 30/30
# 56/56 [==============================] - 4s 80ms/step - loss: 1.3139 - accuracy: 0.5301 - val_loss: 2.9477 - val_accuracy: 0.2174

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.
from glob import glob
import os 
path_list=[x for x in glob(os.path.join(data_dir_train, '*', '*.jpg'))]
cancer_type_list=[os.path.basename(os.path.dirname(i)) for i in glob(os.path.join(data_dir_train, '*', '*.jpg'))]

# %%
original_df=pd.DataFrame(list(dict(zip(path_list,cancer_type_list)).items()),columns=['path','cancer_type'])

# %%
original_df['cancer_type'].value_counts()
# Out:
# pigmented benign keratosis    462
# melanoma                      438
# basal cell carcinoma          376
# nevus                         357
# squamous cell carcinoma       181
# vascular lesion               139
# actinic keratosis             114
# dermatofibroma                 95
# seborrheic keratosis           77
# Name: cancer_type, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder 
from collections import Counter
x,y=original_df['path'],original_df['cancer_type']
y = LabelEncoder().fit_transform(y)
counter = Counter(y)
plt.bar(counter.keys(), counter.values())
plt.show()

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# #### - Class 6 has the least No. of samples
# #### - Which classes dominate the data in terms proportionate number of samples?
# #### - Classes 1,3,4,5 dominate the data in terms of proportionate No.of samples

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Augmentor
#   Downloading Augmentor-0.2.10-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.1)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.10

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
#path_to_training_dataset="/content/drive/MyDrive/Cancer Detection /Train"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline("/content/gdrive/MyDrive/Cancer Detection/Skin cancer ISIC The International Skin Imaging Collaboration/Train",save_format='jpg')
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Cancer Detection/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=919x802 at 0x7F9B5E309250>: 100%|██████████| 500/500 [00:36<00:00, 13.69 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Cancer Detection/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F9B6602DB90>: 100%|██████████| 500/500 [00:41<00:00, 12.12 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Cancer Detection/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=824x719 at 0x7F9B68F12E10>: 100%|██████████| 500/500 [00:41<00:00, 12.05 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Cancer Detection/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=767x576 at 0x7F9B5EF18D10>: 100%|██████████| 500/500 [00:33<00:00, 15.12 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Cancer Detection/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F9B5E5A16D0>: 100%|██████████| 500/500 [00:41<00:00, 12.05 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Cancer Detection/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F9B660D8BD0>: 100%|██████████| 500/500 [00:38<00:00, 13.14 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Cancer Detection/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F9B6630D110>: 100%|██████████| 500/500 [00:42<00:00, 11.65 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Cancer Detection/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F9B7E0E9390>: 100%|██████████| 500/500 [00:43<00:00, 11.45 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Cancer Detection/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F9BFB568ED0>: 100%|██████████| 500/500 [00:40<00:00, 12.20 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
data_dir_train1 = pathlib.Path("/content/gdrive/MyDrive/Cancer Detection/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output")
image_count_train1 = len(list(data_dir_train1.glob('*/*.jpg')))
print(image_count_train1)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
from glob import glob
path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list
# Out:
# []

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new
# Out:
# []

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['path','cancer_type']) 
new_df = original_df.append(df2)

# %%
from sklearn.preprocessing import LabelEncoder 
from collections import Counter
x,y=new_df['path'],new_df['cancer_type']
y = LabelEncoder().fit_transform(y)
counter = Counter(y)
plt.bar(counter.keys(), counter.values())
plt.show()

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
import pathlib
data_dir_train1=pathlib.Path("/content/gdrive/MyDrive/Cancer Detection/Skin cancer ISIC The International Skin Imaging Collaboration/Train")

# %%
data_dir_train1
# Out:
# PosixPath('/content/gdrive/MyDrive/Cancer Detection/Skin cancer ISIC The International Skin Imaging Collaboration/Train')

# %%
image_count_train1 = len(list(data_dir_train1.glob('*/*.jpg')))
print(image_count_train1)
# Out:
# 2239

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential


data_dir_train1=pathlib.Path("/content/gdrive/MyDrive/Cancer Detection/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output")
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train1,
  seed=123,
  validation_split = 0.2,
  subset = "training",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4500 files belonging to 9 classes.
# Using 3600 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train1,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4500 files belonging to 9 classes.
# Using 900 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
## your code goes here
model=Sequential([
                  layers.experimental.preprocessing.Rescaling(1./255,input_shape=(img_height,img_width,3)),
                  layers.Conv2D(16,3,padding='same',activation='relu'),
                  layers.MaxPool2D(),
                  layers.Conv2D(32,3,padding='same',activation='relu'),
                  layers.MaxPool2D(),
                  layers.Conv2D(64,3,padding='same',activation='relu'),
                  layers.MaxPool2D(),
                  layers.Flatten(),
                  layers.Dense(128,activation='relu'),
                  layers.Dense(9,activation='softmax')
              ])

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# Train the Model
epochs = 50
## Your code goes here, use 50 epochs.
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 113/113 [==============================] - 18s 54ms/step - loss: 1.7269 - accuracy: 0.3711 - val_loss: 1.3912 - val_accuracy: 0.5011
# Epoch 2/50
# 113/113 [==============================] - 3s 23ms/step - loss: 1.3687 - accuracy: 0.5194 - val_loss: 1.3264 - val_accuracy: 0.5322
# Epoch 3/50
# 113/113 [==============================] - 3s 23ms/step - loss: 1.2264 - accuracy: 0.5656 - val_loss: 1.2828 - val_accuracy: 0.5533
# Epoch 4/50
# 113/113 [==============================] - 3s 23ms/step - loss: 1.1022 - accuracy: 0.6067 - val_loss: 1.1148 - val_accuracy: 0.6044
# Epoch 5/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.9723 - accuracy: 0.6503 - val_loss: 1.1769 - val_accuracy: 0.5833
# Epoch 6/50
# 113/113 [==============================] - 3s 23ms/step - loss: 0.8621 - accuracy: 0.6939 - val_loss: 1.0606 - val_accuracy: 0.6389
# Epoch 7/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.7034 - accuracy: 0.7472 - val_loss: 1.0703 - val_accuracy: 0.6711
# Epoch 8/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.5940 - accuracy: 0.7933 - val_loss: 0.9047 - val_accuracy: 0.7267
# Epoch 9/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.5388 - accuracy: 0.8111 - val_loss: 1.0619 - val_accuracy: 0.6878
# Epoch 10/50
# 113/113 [==============================] - 3s 23ms/step - loss: 0.4340 - accuracy: 0.8547 - val_loss: 1.0243 - val_accuracy: 0.7156
# Epoch 11/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.3801 - accuracy: 0.8667 - val_loss: 1.0211 - val_accuracy: 0.7411
# Epoch 12/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.2864 - accuracy: 0.9072 - val_loss: 1.0125 - val_accuracy: 0.7411
# Epoch 13/50
# 113/113 [==============================] - 3s 23ms/step - loss: 0.2496 - accuracy: 0.9172 - val_loss: 1.1126 - val_accuracy: 0.7322
# Epoch 14/50
# 113/113 [==============================] - 3s 23ms/step - loss: 0.2279 - accuracy: 0.9222 - val_loss: 1.1434 - val_accuracy: 0.7556
# Epoch 15/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.2724 - accuracy: 0.9078 - val_loss: 1.0424 - val_accuracy: 0.7667
# Epoch 16/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.1974 - accuracy: 0.9378 - val_loss: 1.2249 - val_accuracy: 0.7733
# Epoch 17/50
# 113/113 [==============================] - 3s 23ms/step - loss: 0.1728 - accuracy: 0.9439 - val_loss: 1.2906 - val_accuracy: 0.7600
# Epoch 18/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.1275 - accuracy: 0.9525 - val_loss: 1.2554 - val_accuracy: 0.7889
# Epoch 19/50
# 113/113 [==============================] - 3s 23ms/step - loss: 0.0990 - accuracy: 0.9686 - val_loss: 1.3074 - val_accuracy: 0.7878
# Epoch 20/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.1066 - accuracy: 0.9608 - val_loss: 1.3406 - val_accuracy: 0.7789
# Epoch 21/50
# 113/113 [==============================] - 3s 23ms/step - loss: 0.0938 - accuracy: 0.9669 - val_loss: 1.2551 - val_accuracy: 0.7933
# Epoch 22/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0910 - accuracy: 0.9667 - val_loss: 1.2255 - val_accuracy: 0.7956
# Epoch 23/50
# 113/113 [==============================] - 3s 23ms/step - loss: 0.0698 - accuracy: 0.9736 - val_loss: 1.3453 - val_accuracy: 0.8033
# Epoch 24/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0629 - accuracy: 0.9761 - val_loss: 1.1467 - val_accuracy: 0.8089
# Epoch 25/50
# 113/113 [==============================] - 3s 23ms/step - loss: 0.0555 - accuracy: 0.9778 - val_loss: 1.2193 - val_accuracy: 0.7933
# Epoch 26/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0606 - accuracy: 0.9764 - val_loss: 1.3243 - val_accuracy: 0.7956
# Epoch 27/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0523 - accuracy: 0.9769 - val_loss: 1.3368 - val_accuracy: 0.7844
# Epoch 28/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0581 - accuracy: 0.9761 - val_loss: 1.2850 - val_accuracy: 0.7878
# Epoch 29/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0695 - accuracy: 0.9728 - val_loss: 1.3764 - val_accuracy: 0.8067
# Epoch 30/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.2292 - accuracy: 0.9206 - val_loss: 1.2672 - val_accuracy: 0.7333
# Epoch 31/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.1575 - accuracy: 0.9483 - val_loss: 1.2405 - val_accuracy: 0.7800
# Epoch 32/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0961 - accuracy: 0.9697 - val_loss: 1.3817 - val_accuracy: 0.7911
# Epoch 33/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0872 - accuracy: 0.9689 - val_loss: 1.5192 - val_accuracy: 0.7811
# Epoch 34/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0728 - accuracy: 0.9767 - val_loss: 1.3849 - val_accuracy: 0.7856
# Epoch 35/50
# 113/113 [==============================] - 3s 28ms/step - loss: 0.0593 - accuracy: 0.9758 - val_loss: 1.4933 - val_accuracy: 0.7844
# Epoch 36/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0474 - accuracy: 0.9808 - val_loss: 1.5030 - val_accuracy: 0.8022
# Epoch 37/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0430 - accuracy: 0.9806 - val_loss: 1.5077 - val_accuracy: 0.7944
# Epoch 38/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0408 - accuracy: 0.9814 - val_loss: 1.4351 - val_accuracy: 0.7956
# Epoch 39/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0405 - accuracy: 0.9819 - val_loss: 1.4894 - val_accuracy: 0.7878
# Epoch 40/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0389 - accuracy: 0.9817 - val_loss: 1.5841 - val_accuracy: 0.7956
# Epoch 41/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0374 - accuracy: 0.9831 - val_loss: 1.7500 - val_accuracy: 0.7922
# Epoch 42/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0365 - accuracy: 0.9814 - val_loss: 1.5062 - val_accuracy: 0.7956
# Epoch 43/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0373 - accuracy: 0.9825 - val_loss: 1.5250 - val_accuracy: 0.8044
# Epoch 44/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0643 - accuracy: 0.9764 - val_loss: 1.5176 - val_accuracy: 0.7733
# Epoch 45/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.1751 - accuracy: 0.9403 - val_loss: 1.4588 - val_accuracy: 0.7344
# Epoch 46/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.1727 - accuracy: 0.9461 - val_loss: 1.7544 - val_accuracy: 0.7211
# Epoch 47/50
# 113/113 [==============================] - 3s 23ms/step - loss: 0.1033 - accuracy: 0.9653 - val_loss: 1.8356 - val_accuracy: 0.7467
# Epoch 48/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0481 - accuracy: 0.9806 - val_loss: 1.6111 - val_accuracy: 0.7900
# Epoch 49/50
# 113/113 [==============================] - 3s 23ms/step - loss: 0.0429 - accuracy: 0.9811 - val_loss: 1.6447 - val_accuracy: 0.7767
# Epoch 50/50
# 113/113 [==============================] - 3s 24ms/step - loss: 0.0367 - accuracy: 0.9819 - val_loss: 1.6305 - val_accuracy: 0.7911

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?
# After augmentation with augmentor library, we are able to balance the class and built a good Model.
# Training Accuracy=96%
# Validation Accuracy=82%
# Thus Model is generalisable model now.
