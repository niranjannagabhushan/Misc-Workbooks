# %%
a= []
type(a)
# Out:
# list

# %%
b= [1,2,3,4,5,6,7]
print(b)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
c=['BEPEC',1.2,0]
print(c)
# Out:
# ['BEPEC', 1.2, 0]

# %%
d= [1,7,6,[2,3,4,5]]
print(d)
# Out:
# [1, 7, 6, [2, 3, 4, 5]]

# %%
shoplist = ['apple','mango','carrot','banana']
print(shoplist)
# Out:
# ['apple', 'mango', 'carrot', 'banana']

# %%
print('ihave', len(shoplist), 'items to purchase')
# Out:
# ihave 4 items to purchase

# %%
shoplist.append('tomato')

# %%
print(shoplist)
# Out:
# ['apple', 'mango', 'carrot', 'banana', 'tomato']

# %%
shoplist.extend(['pen','paper'])

# %%
shoplist
# Out:
# ['apple', 'mango', 'carrot', 'banana', 'tomato', 'pen', 'paper']

# %%
print(shoplist)
# Out:
# ['apple', 'mango', 'carrot', 'banana', 'tomato', 'pen', 'paper']

# %%
shoplist[:2]
# Out:
# ['apple', 'mango']

# %%
shoplist[-2]
# Out:
# 'pen'

# %%
shoplist[2][4]
# Out:
# 'o'

# %%
shoplist[5][1]
# Out:
# 'e'
