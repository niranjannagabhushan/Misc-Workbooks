# %%
l=[2,3,4.5,6.7,8+9j,'skjl','qwerty',True,False,]

# %%
l.append(12)

# %%
l
# Out:
# [2, 3, 4.5, 6.7, (8+9j), 'skjl', 'qwerty', True, False, 12]

# %%
l[3:5:1]
# Out:
# [6.7, (8+9j)]

# %%
l[::-1]
# Out:
# [12, False, True, 'qwerty', 'skjl', (8+9j), 6.7, 4.5, 3, 2]

# %%
l[-1:-4]
# Out:
# []

# %%
dict = {"a":100 , "b":200 , "c":300 , "d":400 }

# %%
dict.pop("a")
# Out:
# 100

# %%
dict
# Out:
# {'b': 200, 'c': 300, 'd': 400}

# %%
dict.update("a":100)
# Out:
#   File "<ipython-input-23-0b5e5569b4fb>", line 1
#     dict.update("a":100)
#                    ^
# SyntaxError: invalid syntax

# %%
dict.

# %%
print(type{})
# Out:
#   File "<ipython-input-24-52f8612164d7>", line 1
#     print(type{})
#               ^
# SyntaxError: invalid syntax

# %%
m=[1,2,3]
n=[4,5,6]
m+n
# Out:
# [1, 2, 3, 4, 5, 6]
