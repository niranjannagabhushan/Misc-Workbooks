# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('popularity.csv')

# %%
df.describe()
# Out:
#          timedelta   n_tokens_title   n_tokens_content   n_unique_tokens  \
# count  8599.000000      8599.000000        8599.000000       8599.000000
# mean    653.040935         9.762996         480.181882          0.561861
# std      47.231697         1.956879         397.731123          0.119973
# min     569.000000         2.000000           0.000000          0.000000
# 25%     612.000000         8.000000         221.000000          0.488669
# 50%     655.000000        10.000000         354.000000          0.561475
# 75%     695.000000        11.000000         621.000000          0.634695
# max     731.000000        18.000000        4125.000000          1.000000
#
#         n_non_stop_words   n_non_stop_unique_tokens    num_hrefs  \
# count        8599.000000                8599.000000  8599.000000
# mean            0.991743                   0.704797     9.630887
# std             0.090496                   0.122732     9.992545
# ...

# %%
df[' shares'].percentile(df,0.78)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-296420d11eb7> in <module>()
# ----> 1 df[' shares'].percentile(df,0.78)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'percentile'

# %%
df[' shares']
# Out:
# 0        593.0
# 1        711.0
# 2       1500.0
# 3       1200.0
# 4        505.0
#          ...
# 8595    3200.0
# 8596    1100.0
# 8597    1400.0
# 8598    3900.0
# 8599       NaN
# Name:  shares, Length: 8600, dtype: float64

# %%
series_1 = pd.Series(df[' shares'])
print(series_1)
# Out:
# 0        593.0
# 1        711.0
# 2       1500.0
# 3       1200.0
# 4        505.0
#          ...
# 8595    3200.0
# 8596    1100.0
# 8597    1400.0
# 8598    3900.0
# 8599       NaN
# Name:  shares, Length: 8600, dtype: float64
