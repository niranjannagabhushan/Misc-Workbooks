# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv("INR=X.csv")
print(data.head())
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume
# 0  2020-05-25  75.985001  76.129501  75.757500  75.985001  75.985001       0
# 1  2020-05-26  75.873596  76.110001  75.404999  76.110001  76.110001       0
# 2  2020-05-27  75.489502  76.000000  75.381302  75.820000  75.820000       0
# 3  2020-05-28  75.885696  76.129997  75.634499  76.129997  76.129997       0
# 4  2020-05-29  75.959999  75.959999  75.426300  75.959999  75.959999       0

# %%
plt.figure(figsize=(10, 4))
plt.title("INR - USD Exchange Rate")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
print(data.corr())
sns.heatmap(data.corr())
plt.show()
# Out:
#                Open      High       Low     Close  Adj Close  Volume
# Open       1.000000  0.984714  0.983140  0.994685   0.994685     NaN
# High       0.984714  1.000000  0.981190  0.984740   0.984740     NaN
# Low        0.983140  0.981190  1.000000  0.985341   0.985341     NaN
# Close      0.994685  0.984740  0.985341  1.000000   1.000000     NaN
# Adj Close  0.994685  0.984740  0.985341  1.000000   1.000000     NaN
# Volume          NaN       NaN       NaN       NaN        NaN     NaN

# %%
x = data[["Open", "High", "Low"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

# %%
data = pd.DataFrame(data={"Predicted Rate": ypred.flatten()})
print(data.head())
# Out:
#    Predicted Rate
# 0       74.727402
# 1       73.682404
# 2       73.150902
# 3       73.550003
# 4       73.087601
