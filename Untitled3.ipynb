# %%
print (ord('c')-ord('a'))
# Out:
# 2

# %%
print(float("1,3"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-aca0788302f1> in <module>()
# ----> 1 print(float("1,3"))
#
# ValueError: could not convert string to float: '1,3'

# %%
try:
  print("5"/0)
except ArithmeticError:
  print("arith")
except ZeroDivisionError
  print("zero")
except: 
  print ("some")
# Out:
#   File "<ipython-input-6-a38db5fb788e>", line 6
#     except ZeroDivisionError
#                             ^
# SyntaxError: invalid syntax

# %%
"5"/0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-b2ec73d5599b> in <module>()
# ----> 1 "5"/0
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
print( 3 * 'abc' + 'xyz')
# Out:
# abcabcabcxyz

# %%
print(chr(ord('z')-2))
# Out:
# x

# %%
print('Mike'>"Mikey")
# Out:
# False

# %%
assert var ==0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-8540cba6ff42> in <module>()
# ----> 1 assert var ==0
#
# NameError: name 'var' is not defined

# %%
x ='\''
print(len(x))
# Out:
# 1

# %%
import calendar

c= calendar.Calendar()

for weekday in c.iterweekdays():
  print(weekday,end=" ")
# Out:
# 0 1 2 3 4 5 6

# %%
b = bytearray(3)
print (b)
# Out:
# bytearray(b'\x00\x00\x00')

# %%
def I():
  s= 'abcdef'
  for c in s[::2]:
    yield c

for x in I():
  print (x, end='')
# Out:
# ace

# %%
import calendar
print(calendar.weekheader(2))
# Out:
# Mo Tu We Th Fr Sa Su

# %%
my_tuple = (0,1,2,3,4,5,6)
foo = list (filter (lambda x: x-0 and x-1, my_tuple))
print(foo)
# Out:
# [2, 3, 4, 5, 6]

# %%
from datetime import date

date_1 = date (1992, 1, 16) 
date_2 = date (1991, 2, 5)

print (date_1 - date_2)
# Out:
# 345 days, 0:00:00

# %%
import os

os.mkdir ('thumbnails')

os.chdir ('thumbnails')

sizes = ['small', 'medium', 'large']

for size in sizes:

  os.mkdir(size)

print (os.listdir())
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-35-1738c66cf0c1> in <module>()
#       1 import os
#       2
# ----> 3 os.mkdir ('thumbnails')
#       4
#       5 os.chdir ('thumbnails')
#
# FileExistsError: [Errno 17] File exists: 'thumbnails'

# %%
from datetime import datetime

datetime = datetime (2019, 11, 27, 11, 27, 22) 
print (datetime.strftime ('%y/%B/%d %H:%M:%S'))
# Out:
# 19/November/27 11:27:22

# %%
def fun (n) :
  s= '+'
  for i in range (n):
      s += s
  yield s

for x in fun (2):

  print( x, end='')
# Out:
# ++++

# %%
def o (p):
  def q():
    return '*' * p
  return q

r = o(1)

s = o (2)

print (r () + s() )
# Out:
# ***
