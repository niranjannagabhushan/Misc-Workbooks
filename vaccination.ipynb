# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("newvaccine.csv")
data.head()
# Out:
#       location  ...                                     source_website
# 0  Afghanistan  ...                           https://covid19.who.int/
# 1      Albania  ...  https://shendetesia.gov.al/vaksinimi-anticovid...
# 2      Algeria  ...  https://www.echoroukonline.com/%d9%84%d9%82%d8...
# 3      Andorra  ...          https://www.govern.ad/covid19_newsletter/
# 4       Angola  ...                           https://covid19.who.int/
#
# [5 rows x 6 columns]

# %%
pd.to_datetime(data.last_observation_date)
data.location.value_counts()
# Out:
# Kazakhstan       1
# Zambia           1
# Colombia         1
# Argentina        1
# Guinea-Bissau    1
#                 ..
# Iran             1
# Bermuda          1
# Aruba            1
# Samoa            1
# Mauritius        1
# Name: location, Length: 211, dtype: int64

# %%
data.vaccines.value_counts()
# Out:
# Oxford/AstraZeneca                                                                    56
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                         18
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                                          14
# Oxford/AstraZeneca, Pfizer/BioNTech                                                   13
# Oxford/AstraZeneca, Sinopharm/Beijing                                                 11
# Pfizer/BioNTech                                                                       11
# Moderna, Pfizer/BioNTech                                                               9
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac                                           9
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V                      8
# Sputnik V                                                                              6
# Sinopharm/Beijing                                                                      5
# Oxford/AstraZeneca, Sinovac                                                            4
# Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac                                         3
# Oxford/AstraZeneca, Sputnik V                                                          3
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V                                3
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing                                 3
# Covaxin, Oxford/AstraZeneca, Sinopharm/Beijing                                         2
# Sinopharm/Beijing, Sputnik V                                                           2
# Pfizer/BioNTech, Sinovac                                                               2
# Covaxin, Oxford/AstraZeneca                                                            2
# Pfizer/BioNTech, Sinopharm/Beijing                                                     2
# Moderna, Oxford/AstraZeneca                                                            2
# Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V                                       2
# Johnson&Johnson, Moderna, Pfizer/BioNTech                                              1
# Johnson&Johnson                                                                        1
# Oxford/AstraZeneca, Sinovac, Sputnik V                                                 1
# Sinopharm/Beijing, Sinopharm/Wuhan, Sinovac                                            1
# CanSino, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V                       1
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V             1
# Moderna, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V                              1
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sputnik V               1
# Abdala, Soberana02                                                                     1
# QazVac, Sinopharm/HayatVax, Sputnik V                                                  1
# Pfizer/BioNTech, Sinovac, Sputnik V                                                    1
# CanSino, Sinopharm/Beijing, Sinovac, Sputnik V                                         1
# Oxford/AstraZeneca, RBD-Dimer, Sputnik V                                               1
# EpiVacCorona, Sputnik V                                                                1
# Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech                                   1
# Covaxin, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V                              1
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinopharm/Wuhan, Sputnik V     1
# Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac, Sputnik V                              1
# Pfizer/BioNTech, Sputnik V                                                             1
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac                        1
# EpiVacCorona, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V                         1
# Name: vaccines, dtype: int64

# %%
df = data[["vaccines", "location"]]
df.head()
# Out:
#                                             vaccines     location
# 0  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...  Afghanistan
# 1  Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...      Albania
# 2                                          Sputnik V      Algeria
# 3                Oxford/AstraZeneca, Pfizer/BioNTech      Andorra
# 4                                 Oxford/AstraZeneca       Angola

# %%
dict_ = {}
for i in df.vaccines.unique():
  dict_[i] = [df["location"][j] for j in df[df["vaccines"]==i].index]

vaccines = {}
for key, value in dict_.items():
  vaccines[key] = set(value)
for i, j in vaccines.items():
  print(f"{i}:>>{j}")
# Out:
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing:>>{'Afghanistan', 'Peru', 'Maldives'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V:>>{'Philippines', 'Bosnia and Herzegovina', 'Albania'}
# Sputnik V:>>{'Algeria', 'Venezuela', 'Guinea', 'Belarus', 'Syria', 'Paraguay'}
# Oxford/AstraZeneca, Pfizer/BioNTech:>>{'Costa Rica', 'Panama', 'Slovenia', 'Andorra', 'Oman', 'Saudi Arabia', 'Jersey', 'Australia', 'Isle of Man', 'Cape Verde', 'Cayman Islands', 'South Korea', 'Sweden'}
# Oxford/AstraZeneca:>>{'Bangladesh', 'Antigua and Barbuda', 'French Polynesia', 'Saint Kitts and Nevis', 'Montserrat', 'Saint Vincent and the Grenadines', 'Sierra Leone', 'Zambia', 'Timor', 'Barbados', 'Mali', 'Ghana', 'Gambia', 'Saint Lucia', 'Saint Helena', 'Tajikistan', 'Trinidad and Tobago', 'Tonga', 'Jamaica', 'Brunei', 'Nigeria', 'Tuvalu', 'Eswatini', 'Georgia', 'Anguilla', 'Liberia', 'Uganda', 'Nauru', 'Democratic Republic of Congo', 'Yemen', 'Vietnam', 'Madagascar', 'Lesotho', 'Ethiopia', 'Bahamas', 'Togo', 'New Caledonia', 'Solomon Islands', 'Belize', 'Taiwan', 'Samoa', 'Kosovo', "Cote d'Ivoire", 'Suriname', 'Botswana', 'Myanmar', 'Angola', 'South Sudan', 'Falkland Islands', 'Bhutan', 'Dominica', 'Grenada', 'Fiji', 'Malawi', 'Sao Tome and Principe', 'Wallis and Futuna'}
# Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V:>>{'Argentina', 'Djibouti'}
# Oxford/AstraZeneca, Sinovac, Sputnik V:>>{'Armenia'}
# Pfizer/BioNTech:>>{'Japan', 'Turks and Caicos Islands', 'Gibraltar', 'Bermuda', 'New Zealand', 'Monaco', 'Slovakia', 'Aruba', 'Greenland', 'Qatar', 'Kuwait'}
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech:>>{'Estonia', 'Ireland', 'Greece', 'Belgium', 'Spain', 'France', 'Germany', 'Iceland', 'Poland', 'Austria', 'Lithuania', 'Bulgaria', 'Italy', 'Malta', 'Latvia', 'Netherlands', 'Czechia', 'Romania'}
# Oxford/AstraZeneca, Sinovac:>>{'Benin', 'Indonesia', 'Azerbaijan', 'Thailand'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V:>>{'North Macedonia', 'Mongolia', 'Bolivia', 'Bahrain', 'Lebanon', 'Serbia', 'Montenegro', 'Moldova'}
# Moderna, Pfizer/BioNTech:>>{'Faeroe Islands', 'Denmark', 'Israel', 'Norway', 'Bonaire Sint Eustatius and Saba', 'Switzerland', 'Singapore', 'Liechtenstein', 'Curacao'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac:>>{'Brazil', 'Northern Cyprus', 'Ecuador', 'Ukraine', 'Malaysia', 'Uruguay', 'El Salvador', 'Colombia', 'Chile'}
# Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac:>>{'Somalia', 'Dominican Republic', 'Cambodia'}
# Oxford/AstraZeneca, Sinopharm/Beijing:>>{'Papua New Guinea', 'Mozambique', 'Cameroon', 'Nepal', 'Namibia', 'Niger', 'Morocco', 'Guinea-Bissau', 'Sri Lanka', 'Iraq', 'Seychelles'}
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech:>>{'Finland', 'Canada', 'Croatia', 'Scotland', 'England', 'Rwanda', 'Sint Maarten (Dutch part)', 'Portugal', 'United Kingdom', 'Wales', 'Guernsey', 'Palestine', 'Luxembourg', 'Northern Ireland'}
# Covaxin, Oxford/AstraZeneca:>>{'India', 'Central African Republic'}
# Sinopharm/Beijing, Sinopharm/Wuhan, Sinovac:>>{'China'}
# Covaxin, Oxford/AstraZeneca, Sinopharm/Beijing:>>{'Mauritius', 'Comoros'}
# Moderna, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V:>>{'Congo'}
# Abdala, Soberana02:>>{'Cuba'}
# Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech:>>{'Cyprus'}
# Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac, Sputnik V:>>{'Egypt'}
# Sinopharm/Beijing:>>{'Mauritania', 'Equatorial Guinea', 'Zimbabwe', 'Gabon', 'Senegal'}
# Moderna, Oxford/AstraZeneca:>>{'Honduras', 'Guatemala'}
# Oxford/AstraZeneca, Sputnik V:>>{'Guyana', 'Nicaragua', 'Kenya'}
# Pfizer/BioNTech, Sinovac:>>{'Turkey', 'Hong Kong'}
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V:>>{'Hungary'}
# Covaxin, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V:>>{'Iran'}
# Pfizer/BioNTech, Sinopharm/Beijing:>>{'Macao', 'Jordan'}
# QazVac, Sinopharm/HayatVax, Sputnik V:>>{'Kazakhstan'}
# Sinopharm/Beijing, Sputnik V:>>{'Kyrgyzstan', 'Laos'}
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sputnik V:>>{'Libya'}
# CanSino, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V:>>{'Mexico'}
# CanSino, Sinopharm/Beijing, Sinovac, Sputnik V:>>{'Pakistan'}
# EpiVacCorona, Sputnik V:>>{'Russia'}
# Pfizer/BioNTech, Sputnik V:>>{'San Marino'}
# Johnson&Johnson:>>{'South Africa'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac:>>{'Sudan'}
# Pfizer/BioNTech, Sinovac, Sputnik V:>>{'Tunisia'}
# EpiVacCorona, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V:>>{'Turkmenistan'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinopharm/Wuhan, Sputnik V:>>{'United Arab Emirates'}
# Johnson&Johnson, Moderna, Pfizer/BioNTech:>>{'United States'}
# Oxford/AstraZeneca, RBD-Dimer, Sputnik V:>>{'Uzbekistan'}

# %%
import plotly.express as px
import plotly.offline as py

vaccine_map = px.choropleth(data, locations = 'iso_code', color = 'vaccines')
vaccine_map.update_layout(height=300, margin={"r":0,"t":0,"l":0,"b":0})
vaccine_map.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d35d1998-373f-4fa5-977e-39ae3c91ed18" class="plotly-graph-div" style="height:300px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d35d1998-373f-4fa5-977e-39ae3c91ed18")) {
#                     Plotly.newPlot(
#                         'd35d1998-373f-4fa5-977e-39ae3c91ed18',
#                         [{"coloraxis": "coloraxis", "geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "iso_code=%{location}<br>vaccines=%{z}", "locations": ["AFG", "ALB", "DZA", "AND", "AGO", "AIA", "ATG", "ARG", "ARM", "ABW", "AUS", "AUT", "AZE", "BHS", "BHR", "BGD", "BRB", "BLR", "BEL", "BLZ", "BEN", "BMU", "BTN", "BOL", "BES", "BIH", "BWA", "BRA", "BRN", "BGR", "KHM", "CMR", "CAN", "CPV", "CYM", "CAF", "CHL", "CHN", "COL", "COM", "COG", "CRI", "CIV", "HRV", "CUB", "CUW", "CYP", "CZE", "COD", "DNK", "DJI", "DMA", "DOM", "ECU", "EGY", "SLV", "OWID_ENG", "GNQ", "EST", "SWZ", "ETH", "FRO", "FLK", "FJI", "FIN", "FRA", "PYF", "GAB", "GMB", "GEO", "DEU", "GHA", "GIB", "GRC", "GRL", "GRD", "GTM", "GGY", "GIN", "GNB", "GUY", "HND", "HKG", "HUN", "ISL", "IND", "IDN", "IRN", "IRQ", "IRL", "IMN", "ISR", "ITA", "JAM", "JPN", "JEY", "JOR", "KAZ", "KEN", "OWID_KOS", "KWT", "KGZ", "LAO", "LVA", "LBN", "LSO", "LBR", "LBY", "LIE", "LTU", "LUX", "MAC", "MDG", "MWI", "MYS", "MDV", "MLI", "MLT", "MRT", "MUS", "MEX", "MDA", "MCO", "MNG", "MNE", "MSR", "MAR", "MOZ", "MMR", "NAM", "NRU", "NPL", "NLD", "NCL", "NZL", "NIC", "NER", "NGA", "MKD", "OWID_CYN", "OWID_NIR", "NOR", "OMN", "PAK", "PSE", "PAN", "PNG", "PRY", "PER", "PHL", "POL", "PRT", "QAT", "ROU", "RUS", "RWA", "SHN", "KNA", "LCA", "VCT", "WSM", "SMR", "STP", "SAU", "OWID_SCT", "SEN", "SRB", "SYC", "SLE", "SGP", "SXM", "SVK", "SVN", "SLB", "SOM", "ZAF", "KOR", "SSD", "ESP", "LKA", "SDN", "SUR", "SWE", "CHE", "SYR", "TWN", "TJK", "THA", "TLS", "TGO", "TON", "TTO", "TUN", "TUR", "TKM", "TCA", "TUV", "UGA", "UKR", "ARE", "GBR", "USA", "URY", "UZB", "VEN", "VNM", "OWID_WLS", "WLF", "YEM", "ZMB", "ZWE"], "name": "", "type": "choropleth", "z": ["Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing", "Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V", "Sputnik V", "Oxford/AstraZeneca, Pfizer/BioNTech", "Oxford/AstraZeneca", "Oxford/AstraZeneca", "Oxford/AstraZeneca", "Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V", "Oxford/AstraZeneca, Sinovac, Sputnik V", "Pfizer/BioNTech", "Oxford/AstraZeneca, Pfizer/BioNTech", "Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech", "Oxford/AstraZeneca, Sinovac", "Oxford/AstraZeneca", "Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V", "Oxford/AstraZeneca", "Oxford/AstraZeneca", "Sputnik V", "Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech", "Oxford/AstraZeneca", "Oxford/AstraZeneca, Sinovac", "Pfizer/BioNTech", "Oxford/AstraZeneca", "Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V", "Moderna, Pfizer/BioNTech", "Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V", "Oxford/AstraZeneca", "Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac", "Oxford/AstraZeneca", "Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech", "Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac", "Oxford/AstraZeneca, Sinopharm/Beijing", "Moderna, Oxford/AstraZeneca, Pfizer/BioNTech", "Oxford/AstraZeneca, Pfizer/BioNTech", "Oxford/AstraZeneca, Pfizer/BioNTech", "Covaxin, Oxford/AstraZeneca", "Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac", "Sinopharm/Beijing, Sinopharm/Wuhan, Sinovac", "Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac", "Covaxin, Oxford/AstraZeneca, Sinopharm/Beijing", "Moderna, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V", "Oxford/AstraZeneca, Pfizer/BioNTech", "Oxford/AstraZeneca", "Moderna, Oxford/AstraZeneca, Pfizer/BioNTech", "Abdala, Soberana02", "Moderna, Pfizer/BioNTech", "Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech", "Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech", "Oxford/AstraZeneca", "Moderna, Pfizer/BioNTech", "Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V", "Oxford/AstraZeneca", "Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac", "Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac", "Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac, Sputnik V", "Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac", "Moderna, Oxford/AstraZeneca, Pfizer/BioNTech", "Sinopharm/Beijin ...
