# %%
import pandas as pd
import numpy as np

# %%
grades = pd.read_csv('grades.csv')

# %%
grades.head()
# Out:
#                                           submission        submit_time
# 0  https://ckd.upgrad.com/UpGrad/73ba5189-94fd-44...  01/03/17-20:28:52
# 1  https://ckd.upgrad.com/UpGrad/185242ff-7508-4c...  01/03/17-20:18:21
# 2  https://ckd.upgrad.com/UpGrad/a353d129-c100-43...  01/03/17-22:37:08
# 3  https://ckd.upgrad.com/UpGrad/002fc912-faa1-49...  01/02/17-21:43:19
# 4  https://ckd.upgrad.com/UpGrad/25cbc4a4-6d49-4f...  01/03/17-15:27:49

# %%
grades
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-3c2f8f6e545b> in <module>()
# ----> 1 grades['submission'] = grades['submission'].str.split(',')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/strings/accessor.py in wrapper(self, *args, **kwargs)
#     113                     f"inferred dtype '{self._inferred_dtype}'."
#     114                 )
# --> 115                 raise TypeError(msg)
#     116             return func(self, *args, **kwargs)
#     117
#
# TypeError: Cannot use .str.split with values of inferred dtype 'bytes'.

# %%
grades = grades[grades['submission'].|S.contains("zip")]
# Out:
#   File "<ipython-input-29-cac27e2bd679>", line 1
#     grades = grades[grades['submission'].|S.contains("zip")]
#                                          ^
# SyntaxError: invalid syntax

# %%
grades.describe
# Out:
# <bound method NDFrame.describe of Empty DataFrame
# Columns: [submission, submit_time]
# Index: []>

# %%
grades.dtypes
# Out:
# submission     object
# submit_time    object
# dtype: object
