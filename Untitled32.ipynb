# %%
import os

# %%
c = os.getcwd()

# %%
c
# Out:
# '/content'

# %%
os.chdir(d:)
# Out:
#   File "<ipython-input-5-fa3773e12c1d>", line 1
#     os.chdir(d:)
#               ^
# SyntaxError: invalid syntax
