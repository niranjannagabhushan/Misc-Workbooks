# %%
print ( bool(0) , bool(3.14) , bool(-9) , bool(1+0.7j))
# Out:
# False True True True

# %%
a=6
b=2
print( a**b ,a//b)
# Out:
# 36 3

# %%
x=100
y=90
print(x & y)
# Out:
# 64

# %%
m=10 
n=50
(m**2>100 & n<100)
# Out:
# True
