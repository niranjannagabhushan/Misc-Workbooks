# %% [markdown]
# Calculating Dot Product
# Description
# Let's look at some code. Find the dot product between the following two vectors:
# a = (3, 4, 5)
# b = (1, 3, 5)
#
# We've pre-written the code needed to calculate the dot product. You just need to type in these vectors (inside the square bracket), and hit Run.
#
# Also, calculate this value by hand. Does the output of the code match your value?

# %% [markdown]
# You can compute cos inverse in Numpy using the function np.arccos() (code shown below). It returns the angle in radians, so you can convert it to degrees by multiplying by
# 180
# π
#  . You can alternatively use this online calculator.
#
#
#
# # cos inverse
# pi = math.pi
# np.arccos(3/(np.sqrt(5)*np.sqrt(2)))*(180/pi) # returns 18.434948822922017

# %% [markdown]
# The following code block demonstrates how to make a matrix in Numpy and extract its rows, columns, etc. Try playing around with the code in your local Python environment:
#
#
#
# import numpy as np
# A = np.array([[1, 2],
#              [2, 0]])
#
# print(A.shape) # shape
# print(A[:, 0]) # first column
# print(A[1, :]) # second row

# %% [markdown]
# Matrix Operations in Numpy
# You can use the np.dot() method to do matrix multiplication in Numpy, as shown below. To add two matrices
# A
#  and
# B
# , you can simply use
# A
# +
# B
# :
#
#
#
# import numpy as np
#
# A = np.array([[1, 2],
#              [2, 0]])
# B = np.array([[0, 1],
#              [-1, 2]])
#
# # matrix addition
# print(A+B)
#
# # matrix product
# print(np.dot(A, B))

# %% [markdown]
# In Numpy, you can compute the transpose of a matrix
# A
#  using
# A
# .
# T
#  as follows:
#
#
#
# import numpy as np
# A = np.array([[1, 3],
#              [2, 0]])
# # transpose
# print(A.T)

# %% [markdown]
# However, it is useful to know how to compute the inverse in Numpy. You can do that using the method np.linalg.inv(A) as shown below. Also, note that matrices in Numpy can be created using either np.matrix() or using np.array().
#
#
#
# # inverse
# A = np.array([[2, 1, -1],
#               [1, 0, -1],
#               [-2, 0, 1]])
#
# np.linalg.inv(A)

# %% [markdown]
# The following code box demonstrates an example of a linear transformation in Numpy. Feel free to play around with the code.
#
#
# # Import libraries
# import numpy as np
#
# # Declare the positive shearing transformation
#
# S = np.matrix([[1,1], [0,1]])
#
# # Declare the vectors that define the corners of the rectangle.
#
# a = np.matrix([[0],[0]])
# b = np.matrix([[2],[0]])
# c = np.matrix([[2],[1]])
# d = np.matrix([[0],[1]])
#
# # Apply the shear transformation to the vectors
#
# a_sheared = S * a
# b_sheared = S * b
# c_sheared = S * c
# d_sheared = S * d
#
# # Print the new vectors after the transformation has been applied
# print ("Point 'a' is at \n",a_sheared)
# print ("Point 'b' is at \n",b_sheared)
# print ("Point 'c' is at \n",c_sheared)
# print ("Point 'd' is at \n",d_sheared)

# %% [markdown]
# The process of calculating determinants of matrices of higher dimensions can be scaled up analogously, though you'll usually use Numpy for that. In Numpy, you can compute the determinant using np.linalg.det() as shown below.
#
#
#
# # determinant
# A = np.array([[2, 3], [-1, 4] ])
# np.linalg.det(A)

# %% [markdown]
# Try executing the following code in a Jupyter notebook to compute the solution to the system shown above. The inverse of a matrix can be computed using 'np.linalg.inv(A)':
#
#
#
# # system of three equations
# A = np.array([[1, 5, -1],
#               [2, 3, -2],
#               [-3, 4, 0]])
# b = np.array([1, 2, 0])
#
# # compute the inverse
# A_inv = np.linalg.inv(A)
#
# # solution: A_inv * b
# x = np.dot(A_inv, b)
# print(x) # returns [ 0.  0. -1.]

# %%
 


import numpy as np

# system of two equations
A = np.array([[1, 2], 
              [3, 6]])
b = np.array([5, 10])

# compute the inverse
A_inv = np.linalg.inv(A)

# solution: A_inv * b
x = np.dot(A_inv, b)
print(x) # returns [-3.00239975e+16  1.50119988e+16]

# %% [markdown]
# Try solving this system using Numpy and observe the result. The matrix version of this problem is:
#
#
#
# A
# x
# =
# b
# , or
#
#
#
# [
# 1
# 2
# 3
# 6
# ]
# [
# x
# y
# ]
# =
# [
# 5
# 10
# ]
#
#
#
# You can use the following code:
#
#
#
# # system of two equations
# A = np.array([[1, 2],
#               [3, 6]])
# b = np.array([5, 10])
#
# # compute the inverse
# A_inv = np.linalg.inv(A)
#
# # solution: A_inv * b
# x = np.dot(A_inv, b)
# print(x) # returns [-3.00239975e+16  1.50119988e+16]Try solving this system using Numpy and observe the result. The matrix version of this problem is:
#
#
#
# A
# x
# =
# b
# , or
#
#
#
# [
# 1
# 2
# 3
# 6
# ]
# [
# x
# y
# ]
# =
# [
# 5
# 10
# ]
#
#
#
# You can use the following code:
#
#
#
# # system of two equations
# A = np.array([[1, 2],
#               [3, 6]])
# b = np.array([5, 10])
#
# # compute the inverse
# A_inv = np.linalg.inv(A)
#
# # solution: A_inv * b
# x = np.dot(A_inv, b)
# print(x) # returns [-3.00239975e+16  1.50119988e+16]Try solving this system using Numpy and observe the result. The matrix version of this problem is:
#
#
#
# A
# x
# =
# b
# , or
#
#
#
# [
# 1
# 2
# 3
# 6
# ]
# [
# x
# y
# ]
# =
# [
# 5
# 10
# ]
#
#
#
# You can use the following code:
#
#
#
# # system of two equations
# A = np.array([[1, 2],
#               [3, 6]])
# b = np.array([5, 10])
#
# # compute the inverse
# A_inv = np.linalg.inv(A)
#
# # solution: A_inv * b
# x = np.dot(A_inv, b)
# print(x) # returns [-3.00239975e+16  1.50119988e+16]

# %% [markdown]
# Least Squares Approximation
# In the previous segment, we saw an example of the following system of equations which did not have a unique solution:
#
#
#
# 2
# x
# −
# y
# −
# z
# =
# 1
#
# 2
# x
# −
# y
# +
# z
# =
# 0
#
# 4
# x
# −
# 2
# y
# −
# 3
# z
# =
# −
# 1
#
#
#
# A
# x
# =
# b
# , where:
#
#
#
# A
# =
# ⎡
# ⎢
# ⎣
# 2
# −
# 1
# −
# 1
# 2
# −
# 1
# 1
# 4
# −
# 2
# −
# 3
# ⎤
# ⎥
# ⎦
# ,
# x
# =
# ⎡
# ⎢
# ⎣
# x
# 1
# x
# 2
# x
# 3
# ⎤
# ⎥
# ⎦
# ,
# b
# =
# ⎡
# ⎢
# ⎣
# 1
# 0
# −
# 1
# ⎤
# ⎥
# ⎦
#
#
#
# If you tried computing the rank of the matrix in Numpy, it would come out to be rank=2. You can use the following code to compute the rank:
#
#
#
# # system of three equations
# A = np.array([[2, -1, -1],
#               [2, -1, 1],
#               [4, -2, -3]])
#
# b = np.array([1, 0, -1])
# np.linalg.matrix_rank(A) # returns 2

# %% [markdown]
# Computing Eigen-stuff in Numpy
# Usually, you would almost never compute the eigenvalues and eigenvectors manually. In Numpy, the np.linalg module comes with a useful function 'eig' which calculates the eigenvalues and eigenvectors of a given matrix. For example, for the matrix
# A
# =
# [
# −
# 1
# 0
# 0
# 1
# ]
#  we had used above, the eigenvalues and eigenvectors can be computed as follows:
#
#
#
# # calculate eigenvalues and eigenvectors
# A = np.array([[-1, 0],
#               [0, 1]])
#
# # c is the array of eigenvalues
# # v is the matrix with eigenvectors as the columns
# c, v = np.linalg.eig(A)
# print(c)
# print(v)
