# %%
y = 2+3*5
print(Y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-36ddd6d98dfb> in <module>()
#       1 y = 2+3*5
# ----> 2 print(Y)
#
# NameError: name 'Y' is not defined

# %%
 x = int(input())
 y = int(input())
 print(x+y)
# Out:
# 2
# 4
# 6

# %%
1 // 2 * 3
# Out:
# 0

# %%
x = int(input())
y = int(input())
x = x//y
y = y//x
print(y)
# Out:
# 2
# 4
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-5-f8f265bff4b6> in <module>()
#       2 y = int(input())
#       3 x = x//y
# ----> 4 y = y//x
#       5 print(y)
#
# ZeroDivisionError: integer division or modulo by zero

# %%
x = int(input())
y = int(input())
x = x%y
x = x%y
y = y%x
print(y)
# Out:
# 11
# 4
# 1

# %%
x =  1 / 2 + 3 // 3 + 4 ** 2
print(x)
# Out:
# 17.5

# %%
x = int(input())
y = int(input())
x = x / y
y = y / x
print(y)
# Out:
# 2
# 4
# 8.0

# %%
1/1
# Out:
# 1.0

# %%
x = input()
y = int(input())
print(x*y)
# Out:
# 3
# 6
# 333333

# %%
x = 1
x = x==x
print(x)
# Out:
# True

# %%
vals = [0,1,2]
vals.insert (0,1)
del vals [1]

# %%
print (vals)
# Out:
# [1, 1, 2]

# %%
sum (vals)
# Out:
# 4

# %%
def fun (inp=2 , out=3)
  return inp*out

print(fun(out=2))
# Out:
#   File "<ipython-input-19-d519b3c01795>", line 1
#     def fun (inp=2 , out=3)
#                            ^
# SyntaxError: invalid syntax

# %%
x = 1 // 5 + 1 / 5
print(x)
# Out:
# 0.2
