# %%
new = ""
for i in "Hello":
  if i ! = "l":
      new +=I
print(new)
# Out:
#   File "<ipython-input-1-1d86a45284d9>", line 3
#     if i ! = "l":
#          ^
# SyntaxError: invalid syntax

# %%
S="Python"

# %%
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ded5ba42480f> in <module>()
# ----> 1 s
#
# NameError: name 's' is not defined

# %%
S
# Out:
# 'Python'

# %%
("a"+S) [1:]
# Out:
# 'Python'
