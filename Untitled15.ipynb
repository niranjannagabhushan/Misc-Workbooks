# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as ply

# %%
df= pd.read_csv('shares.csv')

# %%
df.head()
df.shape
# Out:
# (39644, 1)

# %%
df.index
df.columns
# Out:
# Index([' shares'], dtype='object')

# %%
df1 = df.[' shares']
# Out:
#   File "<ipython-input-61-f046624ece6f>", line 1
#     df1 = df.[' shares']
#              ^
# SyntaxError: invalid syntax
