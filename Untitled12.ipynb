# %%
import numpy as np
import pandas as pd
df = pd.read_csv('https://cdn.upgrad.com/uploads/production/b3467ba4-4e13-44e9-8087-4d7e94cc7586/forestfires.csv')

# %%
df.shape
# Out:
# (517, 13)

# %%
df_1=(df.describe())

# %%
df_1.shape
# Out:
# (8, 11)

# %%
df.shape
# Out:
# (517, 13)

# %%
df.info
# Out:
# <bound method DataFrame.info of    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0>

# %%
df.columns
# Out:
# Index(['X', 'Y', 'month', 'day', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH',
#        'wind', 'rain', 'area'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.describe()
# Out:
#               X    Y      FFMC        DMC          DC       ISI       temp  \
# count  5.000000  5.0   5.00000   5.000000    5.000000  5.000000   5.000000
# mean   7.400000  5.0  89.68000  37.980000  326.000000  7.420000  12.100000
# std    0.547723  1.0   2.12297   9.714268  321.515941  1.848513   4.219005
# min    7.000000  4.0  86.20000  26.200000   77.500000  5.100000   8.200000
# 25%    7.000000  4.0  89.30000  33.300000   94.300000  6.700000   8.300000
# 50%    7.000000  5.0  90.60000  35.400000  102.200000  6.700000  11.400000
# 75%    8.000000  6.0  90.60000  43.700000  669.100000  9.000000  14.600000
# max    8.000000  6.0  91.70000  51.300000  686.900000  9.600000  18.000000
#
#               RH      wind      rain  area
# count   5.000000  5.000000  5.000000   5.0
# mean   62.600000  2.940000  0.040000   0.0
# std    33.148152  2.419297  0.089443   0.0
# min    33.000000  0.900000  0.000000   0.0
# 25%    33.000000  1.300000  0.000000   0.0
# 50%    51.000000  1.800000  0.000000   0.0
# 75%    97.000000  4.000000  0.000000   0.0
# max    99.000000  6.700000  0.200000   0.0

# %%
rows = df.describe
print(len(rows))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-02c3a4cd46db> in <module>()
#       1 rows = df.describe
# ----> 2 print(len(rows))
#
# TypeError: object of type 'method' has no len()

# %%
cols = len(df.columns)
print(cols)
# Out:
# 13

# %%
df.shape
# Out:
# (5, 13)
